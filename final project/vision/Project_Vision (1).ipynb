# %% [markdown]
# #### Load Necessary Libraries

# %%
import os
import sys
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
from skimage import color, io
import cv2
from PIL import Image
import moviepy.editor as mpy
from moviepy.video.io.bindings import mplfig_to_npimage

from IPython.display import Video

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Image Compression using SVD
#
# In this section, we will use the Singular Value Decomposition (SVD) to compress images. To do this, we will first convert an image to grayscale. We will then convert the image to a matrix of doubles. We will then use the SVD to approximate the image matrix by a matrix of lower rank. We will then use the approximation to compress the image.
#
#
# ## Compression Phase
#
# To begin, we will load an image and convert it to grayscale. We will then convert the image to a matrix of doubles. The values in this matrix range from 0 to 255, where 0 represents black and 255 represents white. We will then use the SVD to approximate the image matrix by a matrix of lower rank. We will then use the approximation to compress the image.

# %%
def load_and_preprocess_image(image_path):
  color_image = cv2.imread(image_path)
  gray_img = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)
  return gray_img

# Replace 'path_to_image' with the actual image path
image_path = './baseball.jpg'
image = load_and_preprocess_image(image_path)
plt.imshow(image, cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

# %% [markdown]
# ### Applying SVD on Image
# We apply Singular Value Decomposition (SVD) on the image. We only keep the first 'k' singular values, which represent the most significant features of the image. This step compresses the image by reducing the amount of data needed to represent it.

# %%
def apply_svd(image):
    return np.linalg.svd(image, full_matrices=False)

U, s, V = apply_svd(image)

# %% [markdown]
# #### Choosing the number of singular values to keep
#
# The number of singular values to keep is a hyperparameter. The higher the number of singular values kept, the higher the quality of the image. However, the higher the number of singular values kept, the higher the size of the image. The number of singular values to keep is a trade-off between image quality and image size. To choose the number of singular values to keep, we can use the concept of the explained variance ratio. The explained variance ratio is the ratio of the variance explained by a singular value to the total variance. The explained variance ratio is a measure of the amount of information retained by a singular value. The explained variance ratio is calculated as follows:
#
# $$
# var_k = \frac{\sum_{i=1}^{k} \sigma_i^2}{\sum_{i=1}^{n} \sigma_i^2}
# $$
#
# where $var_k$ is the explained variance ratio, $\sigma_i$ is the $i^{th}$ singular value, and $n$ is the total number of singular values. The explained variance ratio is a measure of the amount of information retained by a singular value. A good heuristic for choosing the number of singular values to keep is to choose the smallest number of singular values that explain a certain percentage of the total variance. For example, if we want to keep 90% of the total variance, we can choose the smallest number of singular values that explain 90% of the total variance.

# %%
# choose the number of singular values to keep
total_variance = np.sum(s**2)
explained_variance_ratio = s**2 / total_variance
sum = 0
k = 0
for i in range(s.shape[0]):
  sum += explained_variance_ratio[i]
  k += 1
  if sum > 0.9:
    break

print('Number of singular values to keep:', k)
# Out:
# Number of singular values to keep: 19

# %% [markdown]
# ### Reconstruction Phase
# After applying SVD on the image, we reconstruct the image using the reduced number of singular values.

# %%
def reconstruct_image(U, s, V, k):
    new_u = U[: , :k]
    new_s = np.diag(s[:k])
    new_Vt = V[ :k , :]
    return np.linalg.multi_dot([new_u, new_s, new_Vt])

reconstructed_image = reconstruct_image(U, s, V, k)
plt.imshow(np.abs(reconstructed_image), cmap='gray')
plt.xticks([])
plt.yticks([])
plt.title('Reconstructed Image')
plt.show()

# %% [markdown]
# # Video Background Removal
#
# In this part, you are supposed to separate the background and foreground of a video using SVD.

# %%
video = mpy.VideoFileClip('randompeoplewalking.mp4')
video.subclip(0, 50).ipython_display(width=500)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='500'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
def resize_frame(frame, scale):
    # Convert the NumPy array to a PIL Image
    pil_image = Image.fromarray(frame)

    # Resize the image
    width, height = pil_image.size
    new_width = int(scale * width)
    new_height = int(scale * height)
    resized_image = pil_image.resize((new_width, new_height))

    # Convert the PIL Image back to a NumPy array
    resized_frame = np.array(resized_image).reshape(resized_image.size[1], resized_image.size[0])

    return resized_frame


def create_data_matrix_from_video(clip, fps, scale):
    frames = []
    for i in range(fps * int(clip.duration)):
        # get the frame at time i
        frame = clip.get_frame(i)

        # convert the frame to grayscale
        gray_frame = rgb2grey(frame)

        # resize the frame
        resized_frame = resize_frame(gray_frame, scale)

        frames.append(resized_frame.reshape(resized_frame.shape[0] * resized_frame.shape[1]))

    # stack frames horizontally
    return np.transpose(frames)


def rgb2grey(rgb):
    return np.dot(rgb[..., :3], [0.299, 0.587, 0.114])

# %%
# change resolution of image
# scale to X percent (100 means no scaling). CHANGE THIS FOR BETTER RESOLUTION
scale = 50
scale /= 100
original_width = video.size[1]
original_height = video.size[0]

dims = (int(original_width * scale), int(original_height * scale))
dims  # single frame dimensions (height x width)
# Out:
# (120, 160)

# %%
fps = 20
M = create_data_matrix_from_video(video, fps, scale)
np.save('sample_data/video_matrix', M)
M.shape, dims
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 350/351, at time 50.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 357/351, at time 51.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 364/351, at time 52.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 371/351, at time 53.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 378/351, at time 54.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 385/351, at time 55.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 392/351, at time 56.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 399/351, at time 57.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 406/351, at time 58.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 413/351, at time 59.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 420/351, at time 60.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 427/351, at time 61.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 434/351, at time 62.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 441/351, at time 63.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 448/351, at time 64.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 455/351, at time 65.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 462/351, at time 66.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 469/351, at time 67.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 476/351, at time 68.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 483/351, at time 69.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 490/351, at time 70.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 497/351, at time 71.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 504/351, at time 72.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 511/351, at time 73.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 518/351, at time 74.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 525/351, at time 75.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 532/351, at time 76.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 539/351, at time 77.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 546/351, at time 78.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 553/351, at time 79.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 560/351, at time 80.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 567/351, at time 81.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 574/351, at time 82.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 581/351, at time 83.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 588/351, at time 84.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 595/351, at time 85.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 602/351, at time 86.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 609/351, at time 87.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 616/351, at time 88.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 623/351, at time 89.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 630/351, at time 90.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 637/351, at time 91.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 644/351, at time 92.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 651/351, at time 93.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 658/351, at time 94.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 665/351, at time 95.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 672/351, at time 96.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 679/351, at time 97.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 686/351, at time 98.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 693/351, at time 99.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 700/351, at time 100.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 707/351, at time 101.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 714/351, at time 102.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 721/351, at time 103.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 728/351, at time 104.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 735/351, at time 105.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 742/351, at time 106.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 749/351, at time 107.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 756/351, at time 108.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 763/351, at time 109.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 770/351, at time 110.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 777/351, at time 111.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 784/351, at time 112.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 791/351, at time 113.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 798/351, at time 114.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 805/351, at time 115.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 812/351, at time 116.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 819/351, at time 117.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 826/351, at time 118.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 833/351, at time 119.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 840/351, at time 120.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 847/351, at time 121.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 854/351, at time 122.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 861/351, at time 123.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 868/351, at time 124.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 875/351, at time 125.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 882/351, at time 126.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 889/351, at time 127.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 896/351, at time 128.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 903/351, at time 129.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 910/351, at time 130.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 917/351, at time 131.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 924/351, at time 132.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 931/351, at time 133.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 938/351, at time 134.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 945/351, at time 135.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 952/351, at time 136.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 959/351, at time 137.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 966/351, at time 138.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 973/351, at time 139.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 980/351, at time 140.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 987/351, at time 141.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 994/351, at time 142.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1001/351, at time 143.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1008/351, at time 144.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1015/351, at time 145.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1022/351, at time 146.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1029/351, at time 147.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1036/351, at time 148.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1043/351, at time 149.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1050/351, at time 150.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1057/351, at time 151.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1064/351, at time 152.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1071/351, at time 153.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1078/351, at time 154.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1085/351, at time 155.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1092/351, at time 156.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1099/351, at time 157.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1106/351, at time 158.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1113/351, at time 159.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1120/351, at time 160.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1127/351, at time 161.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1134/351, at time 162.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1141/351, at time 163.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1148/351, at time 164.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1155/351, at time 165.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1162/351, at time 166.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1169/351, at time 167.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1176/351, at time 168.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1183/351, at time 169.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1190/351, at time 170.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1197/351, at time 171.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1204/351, at time 172.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1211/351, at time 173.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1218/351, at time 174.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1225/351, at time 175.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1232/351, at time 176.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1239/351, at time 177.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1246/351, at time 178.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1253/351, at time 179.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1260/351, at time 180.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1267/351, at time 181.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1274/351, at time 182.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1281/351, at time 183.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1288/351, at time 184.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1295/351, at time 185.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1302/351, at time 186.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1309/351, at time 187.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1316/351, at time 188.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1323/351, at time 189.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1330/351, at time 190.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1337/351, at time 191.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1344/351, at time 192.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1351/351, at time 193.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1358/351, at time 194.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 1365/351, at time 195.00/50.00 sec. Using the last valid frame instead.
# ...
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6664/351, at time 952.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6671/351, at time 953.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6678/351, at time 954.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6685/351, at time 955.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6692/351, at time 956.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6699/351, at time 957.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6706/351, at time 958.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6713/351, at time 959.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6720/351, at time 960.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6727/351, at time 961.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6734/351, at time 962.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6741/351, at time 963.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6748/351, at time 964.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6755/351, at time 965.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6762/351, at time 966.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6769/351, at time 967.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6776/351, at time 968.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6783/351, at time 969.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6790/351, at time 970.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6797/351, at time 971.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6804/351, at time 972.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6811/351, at time 973.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6818/351, at time 974.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6825/351, at time 975.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6832/351, at time 976.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6839/351, at time 977.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6846/351, at time 978.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6853/351, at time 979.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6860/351, at time 980.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6867/351, at time 981.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6874/351, at time 982.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6881/351, at time 983.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6888/351, at time 984.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6895/351, at time 985.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6902/351, at time 986.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6909/351, at time 987.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6916/351, at time 988.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6923/351, at time 989.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6930/351, at time 990.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6937/351, at time 991.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6944/351, at time 992.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6951/351, at time 993.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6958/351, at time 994.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6965/351, at time 995.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6972/351, at time 996.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6979/351, at time 997.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6986/351, at time 998.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file randompeoplewalking.mp4, 230400 bytes wanted but 0 bytes read,at frame 6993/351, at time 999.00/50.00 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# ((19200, 1000), (120, 160))

# %%
test_image = M[:, 50].reshape(dims)
plt.imshow(test_image, cmap='gray')
plt.show()

# %%
k = 20

# Apply SVD to the data matrix
U, s, Vh = apply_svd(M)
U = U[:, :k]
s = s[:k]
Vh = Vh[:k, :]
# Out:
# (1000,)

# %%
# calculate foreground from difference between original and reconstructed image
foreground = np.abs(M - reconstruct_image(U,s,Vh,k))

# %%
foreground_frames = foreground.reshape((dims[0], dims[1], -1))

fig, ax = plt.subplots()


def make_frame(t):
    ax.clear()
    ax.imshow(foreground_frames[..., int(t*fps)], cmap='gray')
    return mplfig_to_npimage(fig)


# save video with gray color
clip = mpy.VideoClip(make_frame=make_frame, duration=50)
clip.write_videofile("out.mp4", codec='mpeg4', fps=fps)
# Out:
# Moviepy - Building video out.mp4.
# Moviepy - Writing video out.mp4
# Moviepy - Done !
# Moviepy - video ready out.mp4
